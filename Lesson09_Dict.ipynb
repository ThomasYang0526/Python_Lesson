# %%
fruits = {'西瓜':15,'香蕉':20,'水蜜桃':25}
noodles = {'牛肉麵':100,'肉絲麵':80,'陽春麵':60}
print(fruits)
print(noodles)
print("字典 fruits 的資料類型是",type(fruits))
# Out:
# {'西瓜': 15, '香蕉': 20, '水蜜桃': 25}
# {'牛肉麵': 100, '肉絲麵': 80, '陽春麵': 60}
# 字典 fruits 的資料類型是 <class 'dict'>

# %%
fruits = {'西瓜':15,'香蕉':20,'水蜜桃':25}
noodles = {'牛肉麵':100,'肉絲麵':80,'陽春麵':60}
print("水蜜桃一斤：",fruits["水蜜桃"],"元")
print("牛肉麵一碗：",noodles["牛肉麵"],"元")
# Out:
# 水蜜桃一斤： 25 元
# 牛肉麵一碗： 100 元

# %%
fruits = {'西瓜':15,'香蕉':20,'水蜜桃':25}
fruits['橘子'] = 18
print(fruits)
print('橘子一斤：',fruits['橘子'],"元")
# Out:
# {'西瓜': 15, '香蕉': 20, '水蜜桃': 25, '橘子': 18}
# 橘子一斤： 18 元

# %%
fruits = {'西瓜':15,'香蕉':20,'水蜜桃':25}
print("舊香蕉的價格一斤：",fruits['香蕉'],'元')
fruits['香蕉'] = 12
print("香蕉的價格一斤：",fruits['香蕉'],'元')
# Out:
# 舊香蕉的價格一斤： 20 元
# 香蕉的價格一斤： 12 元

# %%
fruits = {'西瓜':15,'香蕉':20,'水蜜桃':25}
print("舊的 fruits 內容：",fruits)
del fruits['西瓜']
print("新的 fruits 內容：",fruits)
# Out:
# 舊的 fruits 內容： {'西瓜': 15, '香蕉': 20, '水蜜桃': 25}
# 新的 fruits 內容： {'香蕉': 20, '水蜜桃': 25}

# %%
fruits = {'西瓜':15,'香蕉':20,'水蜜桃':25}
print("舊的 fruits 內容：",fruits)
fruits.clear()
print("新的 fruits 內容：",fruits)
# Out:
# 舊的 fruits 內容： {'西瓜': 15, '香蕉': 20, '水蜜桃': 25}
# 新的 fruits 內容： {}

# %%
soldier0 = {}
print("空小兵的字典",soldier0)
soldier0['tag'] = 'red'
soldier0 ['score'] = 3
print("新小兵字典",soldier0)
# Out:
# 空小兵的字典 {}
# 新小兵字典 {'tag': 'red', 'score': 3}

# %%
fruits = {'西瓜':15,'香蕉':20,'水蜜桃':25,'蘋果':18}
cfruits = fruits.copy()
print("地址：",id(fruits),"fruits 元素：",fruits)
print("地址：",id(cfruits),"cfruits 元素",cfruits)
# Out:
# 地址： 139626912294544 fruits 元素： {'西瓜': 15, '香蕉': 20, '水蜜桃': 25, '蘋果': 18}
# 地址： 139626912294304 cfruits 元素 {'西瓜': 15, '香蕉': 20, '水蜜桃': 25, '蘋果': 18}

# %%
fruits = {'西瓜':15,'香蕉':20,'水蜜桃':25,'蘋果':18}
noodles = {'牛肉麵':100,'肉絲麵':80,'陽春麵':60}
empty_dict = {}
print("fruits 字典元素數量：    ",len(fruits))
print("noodles 字典元素數量：   ",len(noodles))
print("empty_dict 字典元素數量：",len(empty_dict))
# Out:
# fruits 字典元素數量：     4
# noodles 字典元素數量：    3
# empty_dict 字典元素數量： 0

# %%
players = { '王三':'A隊',
            '李四':'A隊',
            '張五':'B隊',
            '林六':'C隊',
            '劉七':'D隊'}
for name,team in players.items():
    print("\n姓名：",name)
    print("隊名：",team)
# Out:
# 姓名： 王三
# 隊名： A隊
#
# 姓名： 李四
# 隊名： A隊
#
# 姓名： 張五
# 隊名： B隊
#
# 姓名： 林六
# 隊名： C隊
#
# 姓名： 劉七
# 隊名： D隊

# %%
players = { '王三':'A隊',
            '李四':'A隊',
            '張五':'B隊',
            '林六':'C隊',
            '劉七':'D隊'}
for name in players.keys():
    print("姓名：",name)
# Out:
# 姓名： 王三
# 姓名： 李四
# 姓名： 張五
# 姓名： 林六
# 姓名： 劉七

# %%
players = { '王三':'A隊',
            '李四':'A隊',
            '張五':'B隊',
            '林六':'C隊',
            '劉七':'D隊'}
for name in players:
    print(name)
    print("%s 我喜歡看你在 %s 的表現" %(name,players[name]))
# Out:
# 王三
# 王三 我喜歡看你在 A隊 的表現
# 李四
# 李四 我喜歡看你在 A隊 的表現
# 張五
# 張五 我喜歡看你在 B隊 的表現
# 林六
# 林六 我喜歡看你在 C隊 的表現
# 劉七
# 劉七 我喜歡看你在 D隊 的表現

# %%
players = { '1王三':'A隊',
            '4李四':'A隊',
            '2張五':'B隊',
            '5林六':'C隊',
            '4劉七':'D隊'}
for name in sorted(players.keys()):
    print(name)
    print("%s 我喜歡看你在 %s 的表現" %(name,players[name]))
# Out:
# 1王三
# 1王三 我喜歡看你在 A隊 的表現
# 2張五
# 2張五 我喜歡看你在 B隊 的表現
# 4劉七
# 4劉七 我喜歡看你在 D隊 的表現
# 4李四
# 4李四 我喜歡看你在 A隊 的表現
# 5林六
# 5林六 我喜歡看你在 C隊 的表現

# %%
players = { '1王三':'A隊',
            '4李四':'A隊',
            '2張五':'B隊',
            '5林六':'C隊',
            '4劉七':'D隊'}
for team in players.values():
    print(team)
# Out:
# A隊
# A隊
# B隊
# C隊
# D隊

# %%
soldier0 = {'tag':'red','score':3,'speed':'slow'}
soldier1 = {'tag':'blue','score':5,'speed':'medium'}
soldier2 = {'tag':'greem','score':10,'speed':'fast'}
armys = [soldier0,soldier1,soldier2]
for army in armys:
    print(army)
# Out:
# {'tag': 'red', 'score': 3, 'speed': 'slow'}
# {'tag': 'blue', 'score': 5, 'speed': 'medium'}
# {'tag': 'greem', 'score': 10, 'speed': 'fast'}

# %%
armys = []
for soldier_name in range(50):
    soldier = {'tag':'red','score':3,'speed':'slow'}
    armys.append(soldier)
for soldier in armys[:3]:    #列印前 3 個小兵
    print(soldier)
#更改編號 36 到 38 的小兵
for soldier in armys[35:38]:
    if soldier['tag'] == 'red':
        soldier['tag'] = 'blue'
        soldier['score'] = 5
        soldier['speed'] = 'medium'
#列印編號 35 到 40 的小兵
print("列印編號 35 到 40 小兵數據")
for soldier in armys[34:40]:
    print(soldier)
# Out:
# {'tag': 'red', 'score': 3, 'speed': 'slow'}
# {'tag': 'red', 'score': 3, 'speed': 'slow'}
# {'tag': 'red', 'score': 3, 'speed': 'slow'}
# 列印編號 35 到 40 小兵數據
# {'tag': 'red', 'score': 3, 'speed': 'slow'}
# {'tag': 'blue', 'score': 5, 'speed': 'medium'}
# {'tag': 'blue', 'score': 5, 'speed': 'medium'}
# {'tag': 'blue', 'score': 5, 'speed': 'medium'}
# {'tag': 'red', 'score': 3, 'speed': 'slow'}
# {'tag': 'red', 'score': 3, 'speed': 'slow'}

# %%
wechat_account = {'cshung':{
                            'last_name':'洪',
                            'first_name':'錦魁',
                            'city':'臺北'},
                   'kevin':{
                            'last_name':'鄭',
                            'first_name':'義盟',
                            'city':'北京'},
                 }
#列印內含 字典的字典
for account,account_info in wechat_account.items():
    print("使用者帳號：",account)
    name = account_info['last_name'] + " " + account_info['first_name']
    print("姓名      ：",name)
    print("城市      ：",account_info['city'])
# Out:
# 使用者帳號： cshung
# 姓名      ： 洪 錦魁
# 城市      ： 臺北
# 使用者帳號： kevin
# 姓名      ： 鄭 義盟
# 城市      ： 北京

# %%
#將清單轉成字典
seq1 = ['name','city']
list_dict1 = dict.fromkeys(seq1)
print("字典1：",list_dict1)
list_dict2 = dict.fromkeys(seq1,'Chicago')
print("字典2：",list_dict2)

#將元組轉成字典
seq2 = ('name','city')
tup_dict1 = dict.fromkeys(seq2)
print("字典3：",tup_dict1)
tup_dict2 = dict.fromkeys(seq2,"New York")
print("字典4",tup_dict2)
# Out:
# 字典1： {'name': None, 'city': None}
# 字典2： {'name': 'Chicago', 'city': 'Chicago'}
# 字典3： {'name': None, 'city': None}
# 字典4 {'name': 'New York', 'city': 'New York'}

# %%
fruits = {'Apple':20,'Orange':25}
ret_value1 = fruits.get('Orange')  # 找到鍵就返回此鍵的值
print("Value = ",ret_value1)
ret_value2 = fruits.get("Grang")   # 找不到鍵就返回 None
print("Value = ",ret_value2)
ret_value3 = fruits.get("Grape",10) # 找不到鍵就返回第2個參數，即預設值
print("Value = ",ret_value3)
# Out:
# Value =  25
# Value =  None
# Value =  10

# %%
person = {'name':'John'}
print("原先字典內容：",person)

#'age'鍵不存在
age = person.setdefault('age')
print("增加 age 鍵",person)
print("age = ",age)

#'sex'鍵不存在
sex = person.setdefault('sex','Male')
print("增加 sex 鍵",person)
print("sex = ",sex)
# Out:
# 原先字典內容： {'name': 'John'}
# 增加 age 鍵 {'name': 'John', 'age': None}
# age =  None
# 增加 sex 鍵 {'name': 'John', 'age': None, 'sex': 'Male'}
# sex =  Male

# %%
fruits = {'apple':20,'banana':15,'orange':22}
ret_value = fruits.pop('orange')
print("傳回刪除元素的值：",ret_value)
print("刪除後的字典內容",fruits)
# Out:
# 傳回刪除元素的值： 22
# 刪除後的字典內容 {'apple': 20, 'banana': 15}
