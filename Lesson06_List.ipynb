# %%
#變數用串列多重指定 學生太多時 不可能一一設立變數
list1=[23,19,22,31,18]
var1,var2,var3,var4,var5=list1
    #若變數個數!=len(list1) 就會發生錯誤
print(var1,var2,var3,var4,var5)
# Out:
# 23 19 22 31 18

# %%
#串列切片
list1=[23,19,22,31,18]
print(len(list1))
print(list1[2:4])
    #list[start:end]
    #會印出start~end-1

#========印出整個list========
print(list1[0:len(list1)])
    #print 0~4, 即全部
print(list1[:])
print(list1)
#===========================

print(list1[:3])
    #0,1,2
print(list1[3:])
    #3~end
print(list1[-2:])
    #後2個
print(list1[0:len(list1):2])
    #0到最後一個，每隔二個
print(list1[::-1])
    #每-1一跳->reverse
# Out:
# 5
# [22, 31]
# [23, 19, 22, 31, 18]
# [23, 19, 22, 31, 18]
# [23, 19, 22, 31, 18]
# [23, 19, 22]
# [31, 18]
# [31, 18]
# [23, 22, 18]
# [18, 31, 22, 19, 23]

# %%
a = [1,2,3,4]
b = a
b[2] = 100
print(a)
# Out:
# [1, 2, 100, 4]

# %%
# min/max/sum
#全為字元/串：mim/max會return min/max unicode
#全為數值：min/max/sum就return相應value
list1=[23,19,22,31,18]
list2=["Curry","Durant","Iquodala","Bell","Thompson"]
list3=list1+list2
list4=['a','x','d','p']
print(min(list1),max(list1),sum(list1))
print(min(list2),max(list2))
print(list3)
print(min(list4),max(list4))
# Out:
# 18 31 113
# Bell Thompson
# [23, 19, 22, 31, 18, 'Curry', 'Durant', 'Iquodala', 'Bell', 'Thompson']
# a x

# %%
print(min(list3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-81a68945a6da> in <module>()
# ----> 1 print(min(list3))
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
print(sum(list3[0:4]))
# Out:
# 95

# %%
#刪除list 的元素
#語法：del list[slicing]
#此種作法當刪除後無法得知刪除的內容->用pop()較優
warriors=["Curry","Durant","Iquodala","Bell","Thompson"]
del warriors[2]
print(warriors)

del warriors[:3]
print(warriors)

warriors=["Curry","Durant","Iquodala","Bell","Thompson"]
del warriors[::2]
print(warriors)
# Out:
# ['Curry', 'Durant', 'Bell', 'Thompson']
# ['Thompson']
# ['Durant', 'Bell']

# %%
#刪除list
#一經刪後即無法復原
x=[1,2,3]
print(x)
del x
print(x)
    #產生如下error
# Out:
# [1, 2, 3]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-29338af38a62> in <module>()
#       4 print(x)
#       5 del x
# ----> 6 print(x)
#       7     #產生如下error
#
# NameError: name 'x' is not defined

# %%
cars = ['toyota','nissan','honda']
print("cars 列表長度是 %d"% len(cars))
if len(cars) != 0:
    del cars[0]
    print("成功刪除 cars 元素")
    print("cars 列表長度是 %d"% len(cars))
else:
    print("cars 內沒有元素")
    
nums = []
print("nuns 列表長度是 %d"% len(nums))
if  len(nums) != 0:
    del nums[0]
    print("成功刪除 nums 元素")
else:
    print("nums 內沒有元素")
# Out:
# cars 列表長度是 3
# 成功刪除 cars 元素
# cars 清單長度是 2
# nuns 列表長度是 0
# nums 內沒有元素

# %% [markdown]
# 6-2 python 簡單的物件導向觀念
# 在物件導向的程式設計（Object Oriented Programming）觀念裡，所有資料皆是一個物件（Object），例如，整數、浮點數、字串或是本章所提的清單皆是一個物件。我們可以為所建閱兵物件設計一些方法（method），供這些物件使用，在這裡所提的方法就是函數，其實方法與函數還是有一些差異，後面還會解說。目前 python 有為一些基本物件提供預設的方法，要使用這些方法可以在物件後先放小數點，再放方法名稱，基本語法格式如下：
# 對象 . 方法 ( )
# 下列將分成幾個小節一步一步以實例說明。
# ————————————————
# 版權聲明：本文為CSDN博主「雙偉科技」的原創文章，遵循CC 4.0 BY-SA版權協議，轉載請附上原文出處連結及本聲明。
# 原文連結：https://blog.csdn.net/ihuxh26556/article/details/108867584

# %%
strN = "DeepStone"
strU = strN.upper()
strL = strN.lower()
strT = strN.title()
print("大寫輸出：",strU,"\n小寫輸出：",strL,"\n第一個字母大寫：",strT)
# Out:
# 大寫輸出： DEEPSTONE
# 小寫輸出： deepstone
# 第一個字母大寫： Deepstone

# %%
cars = ["bmw","benz","audi"]
carF = "我開的第一部車是" + cars[1].title()
carN = "我現在開的車是" + cars[0].upper()
print(carF)
print(carN)
# Out:
# 我開的第一部車是Benz
# 我現在開的車是BMW

# %%
string = "abc"
dir(string)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help(string.islower)
# Out:
# Help on built-in function islower:
#
# islower() method of builtins.str instance
#     Return True if the string is a lowercase string, False otherwise.
#
#     A string is lowercase if all cased characters in the string are lowercase and
#     there is at least one cased character in the string.

# %%
string = ["bmw","benz","audi"]
dir(string)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
cars = []
print("目前清單的內容",cars)
cars.append("Honda")
print("目前清單的內容",cars)
cars.append("Toyota")
print("目前清單的內容",cars)
cars.append("Ford")
print("目前清單的內容",cars)
# Out:
# 目前清單的內容 []
# 目前清單的內容 ['Honda']
# 目前清單的內容 ['Honda', 'Toyota']
# 目前清單的內容 ['Honda', 'Toyota', 'Ford']

# %%
cars = ["Honda","bmw","Toyota","Ford","bmw"]
print("目前清單內容：",cars)
print("使用 [::-1]顛例排序：",cars[::-1])
print("使用 reverse() 顛倒排序")
cars.reverse()
print("新的清單內容：",cars)
# Out:
# 目前清單內容： ['Honda', 'bmw', 'Toyota', 'Ford', 'bmw']
# 使用 [::-1]顛例排序： ['bmw', 'Ford', 'Toyota', 'bmw', 'Honda']
# 使用 reverse() 顛倒排序
# 新的清單內容： ['bmw', 'Ford', 'Toyota', 'bmw', 'Honda']

# %%
cars = ["honda","bmw","toyota","ford"]
print("目前清單內容：",cars)
print("使用 sort() 由小排到大")
cars.sort()
print("排序列表結果：",cars)
nums = [5,3,9,2]
print("目前清單內容：",nums)
print("使用 sort() 由小排到大")
nums.sort()
print("排序列表結果：",nums)
# Out:
# 目前清單內容： ['honda', 'bmw', 'toyota', 'ford']
# 使用 sort() 由小排到大
# 排序列表結果： ['bmw', 'ford', 'honda', 'toyota']
# 目前清單內容： [5, 3, 9, 2]
# 使用 sort() 由小排到大
# 排序列表結果： [2, 3, 5, 9]

# %%
cars = ["honda","bmw","toyota","ford"]
print("目前清單內容：",cars)
print("使用 sort(reverse=True) 由大排到小")
cars.sort(reverse=True)
print("排序列表結果：",cars)
nums = [5,3,9,2]
print("目前清單內容：",nums)
print("使用 sort(reverse=True) 由大排到小")
nums.sort(reverse=True)
print("排序列表結果：",nums)
# Out:
# 目前清單內容： ['honda', 'bmw', 'toyota', 'ford']
# 使用 sort(reverse=True) 由大排到小
# 排序列表結果： ['toyota', 'honda', 'ford', 'bmw']
# 目前清單內容： [5, 3, 9, 2]
# 使用 sort(reverse=True) 由大排到小
# 排序列表結果： [9, 5, 3, 2]

# %% [markdown]
# 6-5-3 sorted() 排序
# 前一小節的 sort() 排序將造成清單元素順序永久更改，如果你不希望更改清單元素的順序，可以使用另一種排序 sorted()，使用這個排序可以獲得想要的排序結果，我們可以用新清單存儲新的排序清單，同時原先清單的順序不更改。它的使用如下：
#
# new_list.sorted( name_list )
#
# 例：這個程式使用 car_sorted() 新清單存儲 car 清單的排序結果，同時使用 num_sorted 新清單存儲 num 清單的排序結果

# %%
cars = ["honda","bmw","toyota","ford"]
print("目前 cars 清單的內容：",cars)
print("使用 sorted() 由小排到大")
cars_sorted = sorted(cars)
print("排序串列結果",cars_sorted)
print("原先串列 cars 內容：",cars)
num = [5,3,9,2]
print("目前 num 清單的內容：",num)
print("使用 sorted() 由小排到大")
num_sorted = sorted(num)
print("排序串列結果",num_sorted)
print("原先串列 num 內容：",num)
# Out:
# 目前 cars 清單的內容： ['honda', 'bmw', 'toyota', 'ford']
# 使用 sorted() 由小排到大
# 排序串列結果 ['bmw', 'ford', 'honda', 'toyota']
# 原先串列 cars 內容： ['honda', 'bmw', 'toyota', 'ford']
# 目前 num 清單的內容： [5, 3, 9, 2]
# 使用 sorted() 由小排到大
# 排序串列結果 [2, 3, 5, 9]
# 原先串列 num 內容： [5, 3, 9, 2]

# %%
cars = ["honda","bmw","toyota","ford"]
print("目前 cars 清單的內容：",cars)
print("使用 sorted(reverse=True) 由大排到小")
cars_sorted = sorted(cars,reverse=True)
print("排序串列結果",cars_sorted)
print("原先串列 cars 內容：",cars)
num = [5,3,9,2]
print("目前 num 清單的內容：",num)
print("使用 sorted(reverse()) 由大排到小")
num_sorted = sorted(num,reverse=True)
print("排序串列結果",num_sorted)
print("原先串列 num 內容：",num)
# Out:
# 目前 cars 清單的內容： ['honda', 'bmw', 'toyota', 'ford']
# 使用 sorted(reverse=True) 由大排到小
# 排序串列結果 ['toyota', 'honda', 'ford', 'bmw']
# 原先串列 cars 內容： ['honda', 'bmw', 'toyota', 'ford']
# 目前 num 清單的內容： [5, 3, 9, 2]
# 使用 sorted(reverse()) 由大排到小
# 排序串列結果 [9, 5, 3, 2]
# 原先串列 num 內容： [5, 3, 9, 2]

# %%
cars = ["toyota","nissan","honda"]
search_str="nissan"
i = cars.index(search_str)
print("所搜尋元素 %s 第一次出現位置索引是 %d" % (search_str,i))
nums = [7,12,30,12,30,9,8]
search_val = 30
j = nums.index(search_val)
print("所搜尋元素 %s 第一次出現位置索引是 %d" % (search_val,j))
# Out:
# 所搜尋元素 nissan 第一次出現位置索引是 1
# 所搜尋元素 30 第一次出現位置索引是 2

# %%
James = ["Lebron James",23,19,22,31,18]    #定義 James 列表
games = len(James)                         #求元素數量
score_Max = max(James[1:games])            #最高得分
i = James.index(score_Max)                 #場次
print(James[0],"在第 %d 場得最高分 %d" % (i,score_Max))
# Out:
# Lebron James 在第 4 場得最高分 31

# %%
cars = ["toyota","nissan","honda"]
search_str = 'nissan'
num1 = cars.count(search_str)
print("所搜尋元素 %s 出現 %d 次" % (search_str,num1))
nums = [17,12,30,12,30,9,8]
search_val = 30
num2 = nums.count(search_val)
print("所奸錄元素 %d 出現 %d 次"%(search_val,num2))
# Out:
# 所搜尋元素 nissan 出現 1 次
# 所奸錄元素 30 出現 2 次

# %%
char = '-'
lst = ['Silicon','Stone','Education']
print(char.join(lst))
car = "***"
lst = ['Silicon','Stone','Education']
print(car.join(lst))
car = '\n'
lst = ['Silicon','Stone','Education']
print(car.join(lst))
# Out:
# Silicon-Stone-Education
# Silicon***Stone***Education
# Silicon
# Stone
# Education

# %%
num = [1,2,3,4,5,[6,7,8]]
num[5]
# Out:
# [6, 7, 8]

# %%
num = [1,2,3,4,5,[6,7,8]]
print(num[5][0])
print(num[5][1])
print(num[5][2])
# Out:
# 6
# 7
# 8

# %%
James = [['Lebron James','SF','12/30/1984'],23,19,22,31,18]
games = len(James)
score_Max = max(James[1:games])
i = James.index(score_Max)
name = James[0][0]
position = James[0][1]
born = James[0][2]
print("姓名    ：",name)
print("位置    ：",position)
print("出生日期：",born)
print("在第 %d 場得最高分 %d" %(score_Max,i))
# Out:
# 姓名    ： Lebron James
# 位置    ： SF
# 出生日期： 12/30/1984
# 在第 31 場得最高分 4

# %%
cars1 = ["toyota","nissan","honda"]
cars2 = ['ford','audi']
print("原先 cars1 清單內容：",cars1)
print("原先 cars2 清單內容：",cars2)
cars1.append(cars2)
print("執行 append() 後清單 cars1 內容",cars1)
print("執行 append() 後清單 cars2 內容",cars2)
# Out:
# 原先 cars1 清單內容： ['toyota', 'nissan', 'honda']
# 原先 cars2 清單內容： ['ford', 'audi']
# 執行 append() 後清單 cars1 內容 ['toyota', 'nissan', 'honda', ['ford', 'audi']]
# 執行 append() 後清單 cars2 內容 ['ford', 'audi']

# %%
cars1 = ["toyota","nissan","honda"]
cars2 = ['ford','audi']
print("原先 cars1 清單內容：",cars1)
print("原先 cars2 清單內容：",cars2)
cars1.extend(cars2)
print("執行 append() 後清單 cars1 內容",cars1)
print("執行 append() 後清單 cars2 內容",cars2)
# Out:
# 原先 cars1 清單內容： ['toyota', 'nissan', 'honda']
# 原先 cars2 清單內容： ['ford', 'audi']
# 執行 append() 後清單 cars1 內容 ['toyota', 'nissan', 'honda', 'ford', 'audi']
# 執行 append() 後清單 cars2 內容 ['ford', 'audi']

# %%
mysports = ['basketball','baseball']
friendsports = mysports
print("我喜歡的運動    ：",mysports)
print("我朋友喜歡的運動：",friendsports)
# Out:
# 我喜歡的運動    ： ['basketball', 'baseball']
# 我朋友喜歡的運動： ['basketball', 'baseball']

# %%
mysports = ['basketball','baseball']
friendspots = mysports
print("我喜歡的運動    ：",mysports)
print("我朋友喜歡的運動：",friendsports)
mysports.append('football')
friendspots.append('soccer')
print("我喜歡的運動    ：",mysports)
print("我朋友喜歡的運動：",friendspots)
# Out:
# 我喜歡的運動    ： ['basketball', 'baseball']
# 我朋友喜歡的運動： ['basketball', 'baseball']
# 我喜歡的運動    ： ['basketball', 'baseball', 'football', 'soccer']
# 我朋友喜歡的運動： ['basketball', 'baseball', 'football', 'soccer']

# %%
mysports = ['basketball','baseball']
friendspots = mysports
print("我喜歡的運動    ：",mysports)
print("我朋友喜歡的運動：",friendsports)
mysports.append('football')
friendspots.append('soccer')
print("--新增運動項目後--")
print("列出 mysports 位址    :",id(mysports))
print("列出 friendspots 位址：",id(friendspots))
print("我喜歡的最新運動    ：",mysports)
print("我朋友喜歡的最新運動：",friendspots)
# Out:
# 我喜歡的運動    ： ['basketball', 'baseball']
# 我朋友喜歡的運動： ['basketball', 'baseball']
# --新增運動項目後--
# 列出 mysports 位址    : 140430335102080
# 列出 friendspots 位址： 140430335102080
# 我喜歡的最新運動    ： ['basketball', 'baseball', 'football', 'soccer']
# 我朋友喜歡的最新運動： ['basketball', 'baseball', 'football', 'soccer']

# %%
mysports = ['basketball','baseball']
friendspots = mysports[:]     #只有這裡和上面例子不同
print("我喜歡的運動    ：",mysports)
print("我朋友喜歡的運動：",friendsports)
mysports.append('football')
friendspots.append('soccer')
print("--新增運動項目後--")
print("列出 mysports 位址    :",id(mysports))
print("列出 friendspots 位址：",id(friendspots))
print("我喜歡的最新運動    ：",mysports)
print("我朋友喜歡的最新運動：",friendspots)
# Out:
# 我喜歡的運動    ： ['basketball', 'baseball']
# 我朋友喜歡的運動： ['basketball', 'baseball']
# --新增運動項目後--
# 列出 mysports 位址    : 140430334771840
# 列出 friendspots 位址： 140430335176128
# 我喜歡的最新運動    ： ['basketball', 'baseball', 'football']
# 我朋友喜歡的最新運動： ['basketball', 'baseball', 'soccer']

# %%
string = 'python'
#正值索引
print("string[0]=",string[0])
print("string[1]=",string[1])
print("string[2]=",string[2])
print("string[3]=",string[3])
print("string[4]=",string[4])
print("string[5]=",string[5])
#負值索引
print("string[-6]=",string[-6])
print("string[-5]=",string[-5])
print("string[-4]=",string[-4])
print("string[-3]=",string[-3])
print("string[-2]=",string[-2])
print("string[-1]=",string[-1])
#多重指定觀念
s1,s2,s3,s4,s5,s6 = string
print("多重指定觀念的輸出測試 = ",s1,s2,s3,s4,s5,s6)
# Out:
# string[0]= p
# string[1]= y
# string[2]= t
# string[3]= h
# string[4]= o
# string[5]= n
# string[-6]= p
# string[-5]= y
# string[-4]= t
# string[-3]= h
# string[-2]= o
# string[-1]= n
# 多重指定觀念的輸出測試 =  p y t h o n

# %%
string = "Deep Learning"
print("列印 string 第 1-3 元素:",string[0:3])
print("列印 string 第 2-4 元素:",string[2:4])
print("列印 string 第 2，4，6 元素:",string[1:6:2])
print("列印 string 第 1 到最後元素:",string[1:])
print("列印 string 前 3 元素:",string[0:3])
print("列印 string 後 3 元素:",string[-3:])
# Out:
# 列印 string 第 1-3 元素: Dee
# 列印 string 第 2-4 元素: ep
# 列印 string 第 2，4，6 元素: epL
# 列印 string 第 1 到最後元素: eep Learning
# 列印 string 前 3 元素: Dee
# 列印 string 後 3 元素: ing

# %%
x = list("Deep Stone")
print(x)
# Out:
# ['D', 'e', 'e', 'p', ' ', 'S', 't', 'o', 'n', 'e']

# %%
x = list("Deep Stone")
x[5:] = 'Mind'
print(x)
# Out:
# ['D', 'e', 'e', 'p', ' ', 'M', 'i', 'n', 'd']

# %%
str1 = "Silicon Stone Education"
str2 = "DeepStone"
str3 = "深石數位"
sList1 = str1.split()
sList2 = str2.split()
sList3 = str3.split()
print(str1," 清單內容是：",sList1)
print(str1," 列表字數是：",len(sList1))
print(str2," 清單內容是：",sList2)
print(str2," 列表字數是：",len(sList2))
print(str3," 清單內容是：",sList3)
print(str3," 列表字數是：",len(sList3))
# Out:
# Silicon Stone Education  清單內容是： ['Silicon', 'Stone', 'Education']
# Silicon Stone Education  列表字數是： 3
# DeepStone  清單內容是： ['DeepStone']
# DeepStone  列表字數是： 1
# 深石數位  清單內容是： ['深石數位']
# 深石數位  列表字數是： 1

# %%
password = "deepstone"
ch = input("請輸入字元：")
print("in 運算式")
if ch in password:
    print("輸入字元在密碼中")
else:
    print("輸入字元不在密碼中")
    
print("not in 運算式")
if ch not in password:
    print("輸入字元不在密碼中")
else:
    print("輸入字元在密碼中")
# Out:
# 請輸入字元：de
# in 運算式
# 輸入字元在密碼中
# not in 運算式
# 輸入字元在密碼中

# %%
fruits = ['蘋果','香蕉','梨子']
fruit = input("請輸入水果")
if fruit in fruits:
    print("這個水果已經有了")
else:
    fruits.append(fruit)
    print("已經加入水果清單：",fruits)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %%
drinks = {'coffee','tea','wine'}
enumerate_drinks = enumerate(drinks)
print(enumerate_drinks)
print("下列是輸出 enumerate 對象類型")
print(type(enumerate_drinks))
# Out:
# ...
# 下列是輸出 enumerate 對象類型
# <class 'enumerate'>

# %%
drinks = {'coffee','tea','wine'}
enumerate_drinks = enumerate(drinks)
print("轉成列表輸出，初始值是 0 ：",list(enumerate_drinks))

enumerate_drinks = enumerate(drinks,start = 10)
print("轉成列表輸出，初始值是 10：",list(enumerate_drinks))
# Out:
# 轉成列表輸出，初始值是 0 ： [(0, 'wine'), (1, 'coffee'), (2, 'tea')]
# 轉成列表輸出，初始值是 10： [(10, 'wine'), (11, 'coffee'), (12, 'tea')]
