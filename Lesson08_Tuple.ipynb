# %%
numbers1 = (1,2,3,4,5)          # 定義元組元素是整數
fruits = ('apple','orange')     # 定義元組元素是字串
mixed = ('James',50)            # 定義元組元素是不同類型資料
val_tuple =(10,)                # 只有一個元素的元組
print(numbers1)
print(fruits)
print(mixed)
print(val_tuple)
print("元組mixed的資料類型是",type(mixed))
# Out:
# (1, 2, 3, 4, 5)
# ('apple', 'orange')
# ('James', 50)
# (10,)
# 元組mixed的資料類型是 <class 'tuple'>

# %%
numbers1 = (1,2,3,4,5)          # 定義元組元素是整數
fruits = ('apple','orange')     # 定義元組元素是字串
val_tuple =(10,)                # 只有一個元素的元組
print(numbers1[0])
print(numbers1[4])
print(fruits[0])
print(fruits[1])
print(val_tuple[0])
# Out:
# 1
# 5
# apple
# orange
# 10

# %%
keys = ('magic','xaab',9099)        #定義元組元素是字串與數位
for key in keys:
    print(key)
# Out:
# magic
# xaab
# 9099

# %%
fruits = ('apple','orange')
print(fruits[0])
fruits[0] = 'watermelon'
print(fruits[0])
# Out:
# apple
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-82516c059142> in <module>()
#       1 fruits = ('apple','orange')
#       2 print(fruits[0])
# ----> 3 fruits[0] = 'watermelon'
#       4 print(fruits[0])
#
# TypeError: 'tuple' object does not support item assignment

# %%
fruits = ('apple','orange')       #定義元組元素是水果
print('原始 fruits 元組元素')
for fruit in fruits:
    print(fruit)
    
fruits = ('watermelon','grape')    #定義新的元組元素
print('\n新的 fruits 元組元素')
for fruit in fruits:
    print(fruit)
# Out:
# 原始 fruits 元組元素
# apple
# orange
#
# 新的 fruits 元組元素
# watermelon
# grape

# %%
fruits = ('apple','orange','banana','watermelon','grape')
print(fruits[1:3])
print(fruits[:2])
print(fruits[1:])
print(fruits[-2:])
print(fruits[0:5:2])
# Out:
# ('orange', 'banana')
# ('apple', 'orange')
# ('orange', 'banana', 'watermelon', 'grape')
# ('watermelon', 'grape')
# ('apple', 'banana', 'grape')

# %% [markdown]
# 應用在清單上的方法或函數如果不會更改元組內容，則可以將它應用在元組，如 len()。如果會更改元組內容，則不可以將它應用在元組，如 append()、insert() 或 pop()。

# %%
keys = ('magic','xaab',9909)
key = keys.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d89480eea8e8> in <module>()
#       1 keys = ('magic','xaab',9909)
# ----> 2 key = keys.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
keys = ('magic','xaab',9909)
keys.append('secret')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5af41be2664c> in <module>()
#       1 keys = ('magic','xaab',9909)
# ----> 2 keys.append('secret')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
keys = ('magic','xaab',9909)
list_keys = list(keys)
list_keys.append('secret')
print("列印元組 ",keys)
print("列印列表 ",list_keys)
# Out:
# 列印元組  ('magic', 'xaab', 9909)
# 列印列表  ['magic', 'xaab', 9909, 'secret']

# %%
tup = (1,3,5,7,9)
print("tup 最大的值是",max(tup))
print("tup 最小的值是",min(tup))
# Out:
# tup 最大的值是 9
# tup 最小的值是 1

# %%
drinks = ("coffee","tea","wine")
enumerate_drinks = enumerate(drinks)                             # 數值初始是 0   
print("轉成元組輸出，初始值是 0 ：",tuple(enumerate_drinks))
enumerate_drinks = enumerate(drinks,start = 10)                  # 數值初始是 10
print("轉成元組輸出，初始值是 10 ：",tuple(enumerate_drinks))
# Out:
# 轉成元組輸出，初始值是 0 ： ((0, 'coffee'), (1, 'tea'), (2, 'wine'))
# 轉成元組輸出，初始值是 10 ： ((10, 'coffee'), (11, 'tea'), (12, 'wine'))

# %%
fields = ['Name','Age','Hometown']
info = ['peter','30','Chicago']
zipData = zip(fields,info)
print(type(zipData))
player = list(zipData)
print(player)
# Out:
# <class 'zip'>
# [('Name', 'peter'), ('Age', '30'), ('Hometown', 'Chicago')]

# %%
fields = ['Name','Age','Hometown']
info = ['peter','30']
zipData = zip(fields,info)
print(type(zipData))
player = list(zipData)
print(player)
# Out:
# <class 'zip'>
# [('Name', 'peter'), ('Age', '30')]

# %%
fields = ['Name','Age','Hometown']
info = ['peter','30','Chicago']
zipData = zip(fields,info)
print(type(zipData))
player = list(zipData)
print(player)

f,i = zip(*player)
print("fileds：",f)
print("info：",i)
# Out:
# <class 'zip'>
# [('Name', 'peter'), ('Age', '30'), ('Hometown', 'Chicago')]
# fileds： ('Name', 'Age', 'Hometown')
# info： ('peter', '30', 'Chicago')

# %% [markdown]
# 8-12 元組的功能
# 讀者也許好奇，元組的資料結構與清單相同，但是元組有不可更改元素內容的限制，為何 python 要有類似但功能即受限的資料結構存在？原因是元組有下列優點：
# 可更安全地保護資料：
# 程式設計中可能會碰上有些資料是永遠不會改變的情況，將它存儲在元組內，可以安全地被保護。例如，電子郵件的資料結構，影像處理時物件的長，寬或每一圖元的色彩資料，很多是以元組為資料類型。
# 增加程式執行速度：
# 元組結構比清單簡單，佔用較少的系統資源，程式執行時速度比較快。
# 當瞭解了上述元組的優點後，其實未來設計程式時，如果確定資料可以不更改，就儘量使用元組資料類型吧！
# ————————————————
# 版權聲明：本文為CSDN博主「雙偉科技」的原創文章，遵循CC 4.0 BY-SA版權協議，轉載請附上原文出處連結及本聲明。
# 原文連結：https://blog.csdn.net/ihuxh26556/article/details/109198695
