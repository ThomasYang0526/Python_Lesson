# %%
# makefood.py
# 這是一個包含 2 個函數的模組
def make_icecream(*toppings):
    # 列出製作霜淇淋的配料
    print("這個霜淇淋所加配料如下")
    for topping in toppings:
        print("---",topping)

def make_drink(size,drink):
    # 輸入飲料規格與種類，然後輸出飲料
    print("所點飲料如下")
    print("---",size.title())
    print("---",drink.title())
