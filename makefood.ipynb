# %%
# makefood.py
# 这是一个包含 2 个函数的模块
def make_icecream(*toppings):
    # 列出制作冰淇淋的配料
    print("这个冰淇淋所加配料如下")
    for topping in toppings:
        print("---",topping)

def make_drink(size,drink):
    # 输入饮料规格与种类，然后输出饮料
    print("所点饮料如下")
    print("---",size.title())
    print("---",drink.title())
