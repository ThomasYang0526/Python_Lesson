# %% [markdown]
# 集合的基本觀念是無序且每個元素是唯一的，集合元素的內容是不可變的，常見的元素有整數、浮點數、字串、元組等。至於可變內容清單、字典、集合等不可以是集合元素。但是集合本身是可變的，我們可以增加或刪除集合的元素。

# %%
langs = {'Python','C','Java'}
print('列印集合：',langs)
print("列印類別：",type(langs))
# Out:
# 列印集合： {'Python', 'C', 'Java'}
# 列印類別： <class 'set'>

# %%
langs = {'Python','C','Python','Java','C'}
print('列印集合：',langs)
# Out:
# 列印集合： {'Python', 'C', 'Java'}

# %%
#集合由整數所組成
integer_set = {1,2,3,4,5}
print(integer_set)
#集合由不同資料型態所組成
mixed_set = {1,'Python',(2,5,10)}   #因為集合元素是不可變的，如果元組所為清單將出現錯誤
print(mixed_set)
# Out:
# {1, 2, 3, 4, 5}
# {1, (2, 5, 10), 'Python'}

# %%
x = {}
print("列印    ：",x)
print("列印類別：",type(x))
# Out:
# 列印    ： {}
# 列印類別： <class 'dict'>

# %%
empty_dict = {}
print("列印類別：",type(empty_dict))
empty_set = set()
print("列印類別：",type(empty_set))
# Out:
# 列印類別： <class 'dict'>
# 列印類別： <class 'set'>

# %%
x = set("DeepStone mean Deep Learning")
print(x)
print(type(x))
# Out:
# {'g', 'p', 'D', 'L', 'm', 'r', 'n', 'o', 't', 'a', 'i', ' ', 'e', 'S'}
# <class 'set'>

# %%
#方式1
fruits = ['apple','orange','apple','banana','orange']
x = set(fruits)
print(x)
#方式2
y = set(['apple','orange','apple','banana','orange'])
print(y)
# Out:
# {'banana', 'orange', 'apple'}
# {'banana', 'orange', 'apple'}

# %% [markdown]
# 10-2-1 交集（intersection）
# 有 A 和 B 兩個集合，如果想得相同的元素，則可以使用交集。例如，有數學（可想成 A 集合）與物理（可想成 B 集合）2 個夏令營，如果想統計有哪些人同時參加這 2 個夏令營，則可以使用此功能。
#
# 在 Python 語言的交集符號是 “ & ” ，另外，也可以使用 intersection() 方法完成這個工作。
#
# 例：有數學與物理 2 個夏令營，這個程式會列出同時參加這 2 個夏令營的成員。
# ————————————————
# 版權聲明：本文為CSDN博主「雙偉科技」的原創文章，遵循CC 4.0 BY-SA版權協議，轉載請附上原文出處連結及本聲明。
# 原文連結：https://blog.csdn.net/ihuxh26556/article/details/109677665

# %%
math = {'Kevin','Peter','Eric'}      # 設定參加數學夏令營成員
physics = {'Peter','Nelson','Tom'}   # 設定參加物理夏令營成員
both = math & physics
print("同時參加數學與物理夏令營的成員：",both)
# Out:
# 同時參加數學與物理夏令營的成員： {'Peter'}

# %%
A = {1,2,3,4,5}
B = {3,4,5,6,7}
AB = A.intersection(B)
print("A和B的交集是：",AB)
BA = B.intersection(A)
print("B和A的交集是：",BA)
# Out:
# A和B的交集是： {3, 4, 5}
# B和A的交集是： {3, 4, 5}

# %% [markdown]
# 10-2-2 並集（union）
# 有 A 和 B 兩個集合，如果想獲得所有的元素，則可以使用並集，例如，有數學（可想成 A 集合）與物理（可想成 B 集合）2 個夏令營，如果想統計參加這 2 個夏令營的全部成員，則可以使用 此功能
#
# 在 Python 語言的並集符號是 " | "，另外，也可以使用 union() 方法完成這個工作。
#
# 例：有數學與物理 2 個夏令營，這個程式會列出參加這 2 個夏令營的所有成員。
# ————————————————
# 版權聲明：本文為CSDN博主「雙偉科技」的原創文章，遵循CC 4.0 BY-SA版權協議，轉載請附上原文出處連結及本聲明。
# 原文連結：https://blog.csdn.net/ihuxh26556/article/details/109677665

# %%
math = {'Kevin','Peter','Eric'}      # 設定參加數學夏令營成員
physics = {'Peter','Nelson','Tom'}   # 設定參加物理夏令營成員
allmember = math | physics
print("參加數學或物理夏令營的全部成員：",allmember)
# Out:
# 參加數學或物理夏令營的全部成員： {'Eric', 'Tom', 'Peter', 'Nelson', 'Kevin'}

# %%
A = {1,2,3,4,5}
B = {3,4,5,6,7}
AorB = A.union(B)
print("A和B的並集是：",AorB)
BorA = B.union(A)
print("B和A的並集是：",BorA)
# Out:
# A和B的並集是： {1, 2, 3, 4, 5, 6, 7}
# B和A的並集是： {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# 10-2-3 差集（difference）
# 有 A 和 B 兩個集合，如果想獲得屬於 A 集合元素，同時不屬於 B 集合則可以使用差集（A - B ）。如果想獲得屬於 B 集合元素，同時不屬於 A 集合則可以使用差集（B - A）。例如，有數學（可想成 A 集合）與物理（可想成 B 集合） 2 個夏令營，如果想瞭解參加數學夏令營但是沒有參加物理夏令營的成員，則可以使用此功能。
#
# 在 Python 語言的差集符號是 “ - ”，另外，也可以使用 difference() 方法完成這個工作。
#
# 例：有數學與物 2 個夏令營，這個程式會列出參加數學夏令營但是沒有參加物理夏令營所有成員，另處也會列出參加物理夏令營但是沒有參加數學夏令營的所有成員。
# ————————————————
# 版權聲明：本文為CSDN博主「雙偉科技」的原創文章，遵循CC 4.0 BY-SA版權協議，轉載請附上原文出處連結及本聲明。
# 原文連結：https://blog.csdn.net/ihuxh26556/article/details/109677665

# %%
math = {'Kevin','Peter','Eric'}      # 設定參加數學夏令營成員
physics = {'Peter','Nelson','Tom'}   # 設定參加物理夏令營成員
math_only = math - physics
print("參加數學夏令營同時沒有參加物理夏令營的成員：",math_only)
physics_only = physics - math
print("參加物理夏令營同時沒有參加數學夏令營的成員：",physics_only)
# Out:
# 參加數學夏令營同時沒有參加物理夏令營的成員： {'Kevin', 'Eric'}
# 參加物理夏令營同時沒有參加數學夏令營的成員： {'Nelson', 'Tom'}

# %%
A = {1,2,3,4,5}
B = {3,4,5,6,7}
A_B = A.difference(B)
print("A - B 的差集是：",A_B)
B_A = B.difference(A)
print("B - A 的差集是：",B_A)
# Out:
# A - B 的差集是： {1, 2}
# B - A 的差集是： {6, 7}

# %% [markdown]
# 10-2-7 對稱差集（symmetric difference）
# 有 A 和 B 兩個集合，如果想獲得屬於 A 或 B 集合元素，但是排除同時屬於 A 和 B 的元素，則可以使用對稱差集。例如，有數學（可想成 A 集合）與物理（可想成 B 集合）2 個夏令營，如果想統計參加數學夏令營或是參加物理夏令營的成員，但是排除同時參加這 2 個夏令營的成員，則可以使用此功能。更簡單的解釋是只參加一個夏令營的成員。
#
# 在 Python 語言的對稱差集符號是 “ ^ ”，另外，也可使用 symmetric_difference() 方法完成這個工作。
#
# 例：有數學與物理 2 個夏令營，這個程式會列出參加數學夏令營或參加物理夏令營，但是排除同時參加 2 個夏令營的所有成員。
# ————————————————
# 版權聲明：本文為CSDN博主「雙偉科技」的原創文章，遵循CC 4.0 BY-SA版權協議，轉載請附上原文出處連結及本聲明。
# 原文連結：https://blog.csdn.net/ihuxh26556/article/details/109677665

# %%
math = {'Kevin','Peter','Eric'}      # 設定參加數學夏令營成員
physics = {'Peter','Nelson','Tom'}   # 設定參加物理夏令營成員
math_sydi_physics = math ^ physics
print("沒有同時參加數學和物理夏令營的成員：",math_sydi_physics)
# Out:
# 沒有同時參加數學和物理夏令營的成員： {'Eric', 'Kevin', 'Nelson', 'Tom'}

# %%
A = {1,2,3,4,5}
B = {3,4,5,6,7}
A_sydi_B = A.symmetric_difference(B)
print("A和B的對稱差集是：",A_sydi_B)
B_sydi_A = B.symmetric_difference(A)
print("B和A的對稱差集是：",B_sydi_A)
# Out:
# A和B的對稱差集是： {1, 2, 6, 7}
# B和A的對稱差集是： {1, 2, 6, 7}

# %%
A = {1,2,3,4,5}
B = {3,4,5,6,7}
C = {1,2,3,4,5}
print("A與B集合相等：",A == B)
print("A與C集合相等：",A == C)
# Out:
# A與B集合相等： False
# A與C集合相等： True

# %%
A = {1,2,3,4,5}
B = {3,4,5,6,7}
C = {1,2,3,4,5}
print("A與B集合相等：",A != B)
print("A與C集合相等：",A != C)
# Out:
# A與B集合相等： True
# A與C集合相等： False

# %%
fruits = set("orange")
print("字元a是否屬於fruits集合：",'a' in fruits)
print("字元d是否屬於fruits集合：",'d' in fruits)
cars = ("Nissan","Toyota",'Ford')
boolean = "Ford" in cars
print("Ford in cars",boolean)
boolean = "Audi" in cars
print("Audi in cars",boolean)
# Out:
# 字元a是否屬於fruits集合： True
# 字元d是否屬於fruits集合： False
# Ford in cars True
# Audi in cars False

# %%
cities = {'Taipei','Beijing','Tokyo'}
cities.add("Chicago")
print("cities集合內容",cities)
cities.add("Beijing")
print("cities集合內容",cities)
tup = (1,2,3)
cities.add(tup)
print("cities集合內容",cities)
# Out:
# cities集合內容 {'Beijing', 'Tokyo', 'Taipei', 'Chicago'}
# cities集合內容 {'Beijing', 'Tokyo', 'Taipei', 'Chicago'}
# cities集合內容 {'Taipei', 'Tokyo', (1, 2, 3), 'Beijing', 'Chicago'}

# %%
numset = {1,2,3}
deep_numset = numset
deep_numset.add(10)
print("深複製 - 觀察 numset     ：",numset)
print("深複製 - 觀察 deep_numset：",deep_numset)

shallow_numset = numset.copy()
shallow_numset.add(100)
print("深複製 - 觀察 numset     ：",numset)
print("深複製 - 觀察 deep_numset：",shallow_numset)
# Out:
# 深複製 - 觀察 numset     ： {10, 1, 2, 3}
# 深複製 - 觀察 deep_numset： {10, 1, 2, 3}
# 深複製 - 觀察 numset     ： {10, 1, 2, 3}
# 深複製 - 觀察 deep_numset： {1, 2, 3, 100, 10}

# %%
cities = {'Taipei','Beijing','Tokyo'}
print("刪除前的 cities 集合：",cities)
cities.remove('Beijing')
print("刪除後的 cities 集合：",cities)
# Out:
# 刪除前的 cities 集合： {'Beijing', 'Tokyo', 'Taipei'}
# 刪除後的 cities 集合： {'Tokyo', 'Taipei'}

# %%
animals = {'dog','cat','bird'}
print("刪除前的 animals 集合：",animals)
animals.discard('cat')
print("刪除後的 animals 集合：",animals)
animals.discard('pig')
print("刪除後的 animals 集合：",animals)

print("刪除資料存在的傳回值：",animals.discard('dog'))
print("刪除資料存在的傳回值：",animals.discard('pig'))
# Out:
# 刪除前的 animals 集合： {'bird', 'dog', 'cat'}
# 刪除後的 animals 集合： {'bird', 'dog'}
# 刪除後的 animals 集合： {'bird', 'dog'}
# 刪除資料存在的傳回值： None
# 刪除資料存在的傳回值： None

# %%
animals = {'dog','cat','bird'}
print("刪除前的 animals 集合：",animals)
ret_element = animals.pop()
print("刪除後的 animals 集合：",animals)
print("所刪除的元素是       ：",ret_element)
# Out:
# 刪除前的 animals 集合： {'bird', 'dog', 'cat'}
# 刪除後的 animals 集合： {'dog', 'cat'}
# 所刪除的元素是       ： bird

# %%
states = {'Mississippi','Idoho','Florida'}
print("刪除前的 states 集合：",states)
states.clear()
print("刪除後的 states 集合：",states)

#測試刪除空集合
empty_set = set()
print("刪除前的 empty_set 集合：",empty_set)
empty_set.clear()
print("刪除後的 empty_set 集合：",empty_set)
# Out:
# 刪除前的 states 集合： {'Florida', 'Mississippi', 'Idoho'}
# 刪除後的 states 集合： set()
# 刪除前的 empty_set 集合： set()
# 刪除後的 empty_set 集合： set()

# %%
A = {'a','b','c'}
B = {'c','d','e'}
C = {'h','k','p'}
boolean = A.isdisjoint(B)   # 有共同的元素“ c”
print(boolean)
boolean = A.isdisjoint(C)   #沒有共同元素
print(boolean)
# Out:
# False
# True

# %%
A = {'a','b','c'}
B = {'a','b','c','d','e','f','g','k'}
C = {'k','m','n'}
boolean = A.issubset(B)   # 所有的 A 元素皆是 B 的元素
print(boolean)
boolean = C.issubset(B)   #有共同元素 “ k ”
print(boolean)
# Out:
# True
# False

# %%
A = {'a','b','c','d','e','f','g','k'}
B = {'a','b','c'}
C = {'k','m','n'}
boolean = A.issuperset(B)   # 所有的 B 元素皆是 A 的元素
print(boolean)
boolean = A.issuperset(C)   #有共同元素 “ k ”
print(boolean)
# Out:
# True
# False

# %%
A = {'a','b','c','d'}
B = {'a','k','c'}
C = {'c','f','w'}

# A將是A和B的交集
ret_value = A.intersection_update(B)
print(ret_value)
print("A集合：",A)
print("B集合：",B)

# A將是A、B、C的交集
ret_value = A.intersection_update(B,C)
print("A集合：",A)
print("B集合：",B)
print("A集合：",C)
# Out:
# None
# A集合： {'a', 'c'}
# B集合： {'k', 'a', 'c'}
# A集合： {'c'}
# B集合： {'k', 'a', 'c'}
# A集合： {'w', 'c', 'f'}

# %%
cars1 = {'Audi','Ford','Toyota'}
cars2 = {'Nissan','Toyota'}
print("執行 update() 前列出 cars1 和 cars2 內容")
print("cars1：",cars1)
print("cars2：",cars2)
cars1.update(cars2)
print("執行 update() 後列出 cars1 和 cars2 內容")
print("cars1：",cars1)
print("cars2：",cars2)
# Out:
# 執行 update() 前列出 cars1 和 cars2 內容
# cars1： {'Toyota', 'Ford', 'Audi'}
# cars2： {'Toyota', 'Nissan'}
# 執行 update() 後列出 cars1 和 cars2 內容
# cars1： {'Ford', 'Toyota', 'Nissan', 'Audi'}
# cars2： {'Toyota', 'Nissan'}

# %%
cars1 = {'Audi','Ford','Toyota'}
cars2 = {'Nissan','Toyota'}
print("執行 update() 前列出 cars1 和 cars2 內容")
print("cars1：",cars1)
print("cars2：",cars2)
cars1.difference_update(cars2)
print("執行 update() 後列出 cars1 和 cars2 內容")
print("cars1：",cars1)
print("cars2：",cars2)
# Out:
# 執行 update() 前列出 cars1 和 cars2 內容
# cars1： {'Toyota', 'Ford', 'Audi'}
# cars2： {'Toyota', 'Nissan'}
# 執行 update() 後列出 cars1 和 cars2 內容
# cars1： {'Ford', 'Audi'}
# cars2： {'Toyota', 'Nissan'}

# %%
numList = {100,99,64,101,55}
chrList = {'a','x','R','z','b'}
#數值所組成的集合運算
print("列出數值集合的最大值：",max(numList))
print("列出數值集合的最小值：",min(numList))
print("列出數值集合的總和值：",sum(numList))

#數值所組成的集合運算
print("列出字元集合的最大值：",max(chrList))
print("列出字元集合的最小值：",min(chrList))
# Out:
# 列出數值集合的最大值： 101
# 列出數值集合的最小值： 55
# 列出數值集合的總和值： 419
# 列出字元集合的最大值： z
# 列出字元集合的最小值： R

# %%
integer_set = {1,2,3,4,5}
mixed_set = {1,'python',(2,5,10)}
print("integer_set 的長度：",len(integer_set))
print("mixed_set 的長度  ：",len(mixed_set))
# Out:
# integer_set 的長度： 5
# mixed_set 的長度  ： 3

# %%
cars = {'Nissan','Toyota','Ford'}
carslist = sorted(cars)
carslist_reverse = sorted(cars,reverse = True)
print("由小到大排列：",carslist)
print("由大到小排列：",carslist_reverse)
# Out:
# 由小到大排列： ['Ford', 'Nissan', 'Toyota']
# 由大到小排列： ['Toyota', 'Nissan', 'Ford']

# %%
drinks = {'coffee','tea','wine'}
enumerate_drinks = enumerate(drinks)  # 數值的初始是 0
print(enumerate_drinks)  # 傳回 enumerate 物件所在記憶體
print("下列是輸出 enumerate 對象類型")
print(type(enumerate_drinks))

print("\n")
print("下列是轉成列表輸出")
print(list(enumerate_drinks))

print("\n")
print("下列是迴圈輸出")
for item in enumerate(drinks):
    print(item)
print("\n")
for count,item in enumerate(drinks):
    print(count,item)
print("\n")
for count,item in enumerate(drinks,10):
    print(count,item)
# Out:
# ...
# 下列是輸出 enumerate 對象類型
# <class 'enumerate'>
#
#
# 下列是轉成列表輸出
# [(0, 'wine'), (1, 'tea'), (2, 'coffee')]
#
#
# 下列是迴圈輸出
# (0, 'wine')
# (1, 'tea')
# (2, 'coffee')
#
#
# 0 wine
# 1 tea
# 2 coffee
#
#
# 10 wine
# 11 tea
# 12 coffee

# %% [markdown]
# 10-5 凍結集合 frozenset
# set 是可變集合，frozenset 是不可變集合也可直譯為凍結集合，這是一個新的類別，只要設定元素後，這個凍結集合就不能再更改了。如果將元想成不可變清單，凍結集合就是不可變集合。
#
# 凍結集合的不可變特性優點是可以用它作字典的鍵，也可以作為其他集合的元素，凍結集合的建立方式是使用 frozenset() 函數，凍結集合建立完成後，不可使用 add() 或 remove() 更改凍結集合的內容，但是可以執行 intersection()、union()、difference()、symmetric_difference()、copy()、issubset()、issuperset()、isdisjoint() 等方法。
#
# 例：建立凍集合與氣操作。
# ————————————————
# 版權聲明：本文為CSDN博主「雙偉科技」的原創文章，遵循CC 4.0 BY-SA版權協議，轉載請附上原文出處連結及本聲明。
# 原文連結：https://blog.csdn.net/ihuxh26556/article/details/109677665

# %%
x = frozenset([1,3,5])
y = frozenset([5,7,9])
print(x)
print(y)
print("交集：",x & y)
print("並集：",x | y)
a = x & y
print("交集a：",a)
a = x.intersection(y)
print("交集a：",a)
# Out:
# frozenset({1, 3, 5})
# frozenset({9, 5, 7})
# 交集： frozenset({5})
# 並集： frozenset({1, 3, 5, 7, 9})
# 交集a： frozenset({5})
# 交集a： frozenset({5})
