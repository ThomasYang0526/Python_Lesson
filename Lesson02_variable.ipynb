# %%
x = 125
print(x)
# Out:
# 125

# %%
x=y=z=10
print(x,y,z)
# Out:
# 10 10 10

# %%
x,y,z=10,20,30
print(x,y,z)
# Out:
# 10 20 30

# %%
a=100
print(a)
# Out:
# 100

# %%
del a 
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ddddfc91a230> in <module>()
#       1 del a
# ----> 2 print(a)
#
# NameError: name 'a' is not defined

# %%
a=b=c=10
x=a+b+c+12
print(x)
# Out:
# 42

# %%
x += 13
print(x)
# Out:
# 55

# %%
y=a+\
    b+\
    c+\
    12
    #利用 \，後方不可再加任何符號或文字，包括註解
print(y)
# Out:
# 42

# %%
z=(a+    #可加註解
   b+
   c+
   12)
    #利用小括號
print(z)
# Out:
# 42
