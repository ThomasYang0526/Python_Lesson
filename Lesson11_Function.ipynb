# %%
def greeting():
    print("Python 歡迎你")
    print("祝福學習順利")
    print("謝謝")
    
#以下的程式碼也可稱主程序
greeting()
greeting()
greeting()
# Out:
# Python 歡迎你
# 祝福學習順利
# 謝謝
# Python 歡迎你
# 祝福學習順利
# 謝謝
# Python 歡迎你
# 祝福學習順利
# 謝謝

# %%
def greeting(name):
    """Python 函數需傳遞名字 name """
    print("嗨，",name,"早上好")
    
greeting("張三")
# Out:
# 嗨， 張三 早上好

# %%
def greeting(name):
    """Python 函數需傳遞名字 name """
    print("嗨，",name,"早上好")
#注：上面程式先保存不調用

#在 Python 提示資訊環境調用
greeting("張三")
greeting("李四")
# Out:
# 嗨， 張三 早上好
# 嗨， 李四 早上好

# %%
def subtaract(x1,x2):
    '''減去設計'''
    result = x1 - x2
    print(result)
print("本程式會執行 a - b 的運算")

a = int(input("a = "))
b = int(input("b = "))
print("a - b = ",end="")
subtaract(a,b)
# Out:
# 本程式會執行 a - b 的運算
# a = 10
# b = 5
# a - b = 5

# %%
def interest(interest_type,subject):
    '''顯示興趣和主題'''
    print("我的興趣是" + interest_type)
    print("在" + interest_type + "中，最喜歡的是" + subject)
    print()
    
interest("旅遊",'敦煌')
interest("程式設計",'Python')
# Out:
# 我的興趣是旅遊
# 在旅遊中，最喜歡的是敦煌
#
# 我的興趣是程式設計
# 在程式設計中，最喜歡的是Python

# %%
def interest(interest_type,subject):
    '''顯示興趣和主題'''
    print("我的興趣是" + interest_type)
    print("在" + interest_type + "中，最喜歡的是" + subject)
    print()
    
interest(interest_type = "旅遊",subject = "敦煌")
interest(subject = "敦煌" , interest_type = "旅遊")
# Out:
# 我的興趣是旅遊
# 在旅遊中，最喜歡的是敦煌
#
# 我的興趣是旅遊
# 在旅遊中，最喜歡的是敦煌

# %%
def interest(interest_type,subject = '敦煌'):
    '''顯示興趣和主題'''
    print("我的興趣是" + interest_type)
    print("在" + interest_type + "中，最喜歡的是" + subject)
    print()
    
interest("旅遊") 
interest(interest_type = "旅遊")
interest("旅遊",'張家界')
interest(interest_type = "旅遊",subject = '張家界')
interest(subject = '張家界',interest_type = "旅遊")
interest("閱讀",'旅遊類')
# Out:
# 我的興趣是旅遊
# 在旅遊中，最喜歡的是敦煌
#
# 我的興趣是旅遊
# 在旅遊中，最喜歡的是敦煌
#
# 我的興趣是旅遊
# 在旅遊中，最喜歡的是張家界
#
# 我的興趣是旅遊
# 在旅遊中，最喜歡的是張家界
#
# 我的興趣是旅遊
# 在旅遊中，最喜歡的是張家界
#
# 我的興趣是閱讀
# 在閱讀中，最喜歡的是旅遊類

# %%
def greeting(name):
    """Python 函數需傳遞名字 name """
    print("嗨，",name,"早上好")
ret_value = greeting("張三")
print("greeting（）傳回值：",ret_value)
print(ret_value,"的 type：",type(ret_value))
# Out:
# 嗨， 張三 早上好
# greeting（）傳回值： None
# None 的 type： <class 'NoneType'>

# %%
def subtaract(x1,x2):
    '''減去設計'''
    result = x1 - x2
    return result
print("本程式會執行 a - b 的運算")

a = 10
b = 3
print("a - b = ",subtaract(a,b))  # 輸出 a - b 字串和結果
# Out:
# 本程式會執行 a - b 的運算
# a - b =  7

# %%
def mutifunction(x1,x2):
    '''加減乘除'''
    addresult = x1 + x2
    subresult = x1 - x2
    mulresult = x1 * x2
    divresult = x1 / x2
    return addresult,subresult,mulresult,divresult
x1 = x2 = 10
add,sub,mul,div = mutifunction(x1,x2)
print("加法結果：",add)
print("減法結果：",sub)
print("乘法結果：",mul)
print("除法結果：",div)
# Out:
# 加法結果： 20
# 減法結果： 0
# 乘法結果： 100
# 除法結果： 1.0

# %%
def guest_info(firstname,lastname,gender,middlename = ''):
    """整合客戶名字資料"""
    if gender == "男":
        welcome = lastname + middlename + firstname + "先生歡迎你"
    else:
        welcome = lastname + middlename + firstname + "小姐歡迎你"
    return welcome

info1 = guest_info("劉","濤","男")
info2 = guest_info("雨","洪","女","冰")
print(info1)
print(info2)
# Out:
# 濤劉先生歡迎你
# 洪冰雨小姐歡迎你

# %%
def product_msg(customers):
    str1 = "親愛的："
    str2 = "本公司將在 2020 年 12 月 20 日北京舉行產品發表會"
    str3 = "總經理：深石敬上"
    for customer in customers:
        msg = str1 + customer + "\n" + str2 + "\n" + str3
        print(msg,'\n')
        
members = ["張三",'李四',"王五"]
product_msg(members)
# Out:
# 親愛的：張三
# 本公司將在 2020 年 12 月 20 日北京舉行產品發表會
# 總經理：深石敬上
#
# 親愛的：李四
# 本公司將在 2020 年 12 月 20 日北京舉行產品發表會
# 總經理：深石敬上
#
# 親愛的：王五
# 本公司將在 2020 年 12 月 20 日北京舉行產品發表會
# 總經理：深石敬上

# %%
def kitchen(unserved,served):
    ''' 將未服務的餐點轉為已服務 '''
    print("廚房處理顧客所點的餐點")
    while unserved:
        current_meal = unserved.pop()
        #模擬出點餐過程
        print("菜單：",current_meal)
        #將已出餐點轉入已經服務清單
        served.append(current_meal)
        
def show_unserved_meal(unserved):
    ''' 顯示尚未服務的餐點 '''
    print("=== 下列是尚未服務的餐點 ===")
    if not unserved:
        print("*** 沒有點餐 ***",'\n')
    for unserved_meal in unserved:
        print(unserved_meal)
        
def show_served_meal(served):
    ''' 顯示已經服務的餐點 '''
    print("=== 下列是已經服務的餐點 ===")
    if not served:
        print("*** 沒有餐點 ***",'\n')
    for served_meal in served:
        print(served_meal)
        
        
# 列出餐廳處理前的點餐內容
unserved = ['大麥克','勁辣雞腿堡','麥克雞塊']
served = []

#列出餐廳處理後的點餐內容
show_unserved_meal(unserved)
show_served_meal(served)

# 餐廳服務過程
kitchen(unserved,served)
print('\n','=== 廚房處理結束 ===','\n')

#列出餐廳處理後的點餐內容
show_unserved_meal(unserved)
show_served_meal(served)
# Out:
# === 下列是尚未服務的餐點 ===
# 大麥克
# 勁辣雞腿堡
# 麥克雞塊
# === 下列是已經服務的餐點 ===
# *** 沒有餐點 ***
#
# 廚房處理顧客所點的餐點
# 功能表： 麥克雞塊
# 菜單： 勁辣雞腿堡
# 菜單： 大麥克
#
#  === 廚房處理結束 ===
#
# === 下列是尚未服務的餐點 ===
# *** 沒有點餐 ***
#
# === 下列是已經服務的餐點 ===
# 麥克雞塊
# 勁辣雞腿堡
# 大麥克

# %% [markdown]
# 11-5 傳遞任意數量的參數

# %%
def make_icecream(icecream_type,*toppings):
    # 列出製作霜淇淋的配料
    print("這個",icecream_type,"霜淇淋所加配料如下")
    for topping in toppings:
        print("---",topping)
make_icecream("香草",'草莓醬')
print()
make_icecream("芒果",'草莓醬','葡萄乾','巧克功碎片')
# Out:
# 這個 香草 霜淇淋所加配料如下
# --- 草莓醬
#
# 這個 芒果 霜淇淋所加配料如下
# --- 草莓醬
# --- 葡萄乾
# --- 巧克功碎片

# %% [markdown]
# 11-5-3 設計含有一般參數與任意數量的關鍵字參數

# %%
def build_dict(name,age,**players):
    info = {}
    info["Name"] = name
    info["Age"] = age
    for key,value in players.items():
        info[key] =value
    return info

player_dict = build_dict("James",'32',
                        City = 'Cleveland',
                        State = 'Ohio')

print(player_dict)
# Out:
# {'Name': 'James', 'Age': '32', 'City': 'Cleveland', 'State': 'Ohio'}

# %%
def build_dict(name,age,**players):
    info = {}
    info["Name"] = name
    info["Age"] = age
    for key,value in players.items():
        info[key] =value
    return info

player_dict = build_dict("James",'32',
                        City = 'Cleveland',
                        State = 'Ohio')

print(player_dict)
# Out:
# {'Name': 'James', 'Age': '32', 'City': 'Cleveland', 'State': 'Ohio'}

# %%
def printmsg():
    # 函數本身沒有定義變數，只有執行列印全域變數功能
    print("函數列印：",msg)   #列印全域變數
msg = "張三"                  #設定全域變數
print("主程序列印：",msg)     #列印全域變數
printmsg()
# Out:
# 主程序列印： 張三
# 函數列印： 張三

# %%
def printmsg():
    msg = "張三"
    print("函數列印：",msg)
msg = "李四"
print("主程序列印：",msg)
printmsg()
# Out:
# 主程序列印： 李四
# 函數列印： 張三

# %%
def defmsg():
    msg = "張三"
    
def printmsg():
    print(msg)
    
printmsg()
# Out:
# 李四

# %% [markdown]
# 11-8 匿名函數 lambda
# 匿名函數最大特色是可以有許多參數，但是只能有一個程式運算式，然後可以將執行結果返回。
#
# lambda arg1 [ , arg2 , … ,argn ] : expression # agr1 是參數，可以有多個參數
# 例：這是單一參數的匿名函數應用，可以返回平方值。
# 匿名函數的最大優點是可以讓程式變得更簡潔，可參考下列實例.

# %%
square = lambda x:x ** 2
print(square(10))
# Out:
# 100

# %% [markdown]
# filter( function, iterable)
# map ( function , iterable )

# %%
def oddfn(x):
    return x if (x % 2 == 1) else None
mylist = [5,10,15,20,25,30]
filter_object = filter(oddfn,mylist)
print("奇數列表：",[item for item in filter_object])
# Out:
# 奇數列表： [5, 15, 25]

# %%
mylist = [5,10,15,20,25,30]
oddlist = list(filter(lambda x:(x % 2 == 1),mylist))
print("奇數列表：",oddlist)
# Out:
# 奇數列表： [5, 15, 25]

# %%
def fun(arg):
    pass

# %%
def fun(arg):
    pass
print("列出 fun 的 type 類型        ：",type(fun))
print("列出 lambda 的 type 類型     ：",type(lambda x:x))
print("列出內置函數 abs 的 type 類型：",type(abs))
# Out:
# 列出 fun 的 type 類型        ： <class 'function'>
# 列出 lambda 的 type 類型     ： <class 'function'>
# 列出內置函數 abs 的 type 類型： <class 'builtin_function_or_method'>
